# %% [markdown]
# # **Senior Design Project - Brain Machine Interface**
#
#
#
# ### Krithik Parvataneni, Lisa Verma, Tsenbujin Tsendjav, Wencan Yang

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path_to_mat = '/content/drive/Shared drives/EEC174AY Group 8/Dataset/mat_data'
path_to_txt = '/content/drive/Shared drives/EEC174AY Group 8/Dataset/txt_data'
path_to_model = '/content/drive/Shared drives/EEC174AY Group 8/models/'

# %% [markdown]
# ## **All imports used**

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import os
import pandas as pd
import gc
import torch.utils.data as data
import torchvision.datasets as datasets
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D
from keras.layers import Input
from sklearn.preprocessing import StandardScaler
import torch
import numpy as np
import keras

# %% [markdown]
# ## **Load the dataset**

# %% [markdown]
# ## **Data preprocessing**
# ### **Data loader:**

# %%
class DataSet(data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.files = [file.path for file in os.scandir(self.root_dir)]
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        file_path = self.files[idx]
        mat_data = sio.loadmat(file_path)

        all_data = []
        all_data.append(mat_data)

        return all_data

# %%
# 16 channels
class get_data():

    def __init__(self, mat_input, device):
        self.mat_input = mat_input
        self.device = device

    def get_movement(self, channels=None):
        movement_left = []
        movement_right = []
        movement_event = []
        sliced_left = []
        sliced_right = []
        index = []
        movement_event = self.mat_input['eeg']['movement_event'][0][0][0]
        if channels == None:
          channels = [9,11,44,48,18,45,46,55,6,4,20,22,30,0,12,49]
        # get raw dataset
        for i in channels:
            movement_left.append(self.mat_input['eeg']['movement_left'][0][0][i])
            movement_right.append(self.mat_input['eeg']['movement_right'][0][0][i])
        #get onset (starting pt) of movement_event:
        for q in range(len(movement_event)):
            if movement_event[q] == 1:
                  index.append(q)
        #slice movement_left and right to only keep active region:
        for x in range(len(index)):
            temp_left = []
            temp_right = []
            for j in range(len(movement_left)):
                start_index = index[x]
                end_index = start_index + 1536 #three seconds for a period
                temp_left.append(movement_left[j][start_index:end_index])
                temp_right.append(movement_right[j][start_index:end_index])
            sliced_left.append(temp_left)
            sliced_right.append(temp_right)

        sliced_left_tensor = torch.tensor(np.array(sliced_left), device=self.device)
        sliced_right_tensor = torch.tensor(np.array(sliced_right), device=self.device)
        index_tensor = torch.tensor(np.array(index), device=self.device)

        return sliced_left_tensor, index_tensor, sliced_right_tensor

# %%
mat_data = DataSet(path_to_mat)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

move_left = []
move_right = []
move_idx = []
for subject in range(len(mat_data)):
  left = []
  right = []
  index = []
  left, idx, right = get_data(mat_data[subject][0], device).get_movement()
  move_left.append(left)
  move_right.append(right)
  move_idx.append(idx)

# %%
move_left_cpu = move_left[20][1][1].cpu() # [subject][trial][channel]
# Convert tensor to numpy array
left_numpy = move_left_cpu.detach().numpy()

plt.plot(left_numpy)
plt.ylabel('One trial of unscaled signal')
plt.show()

# %%
def filter(input_tensor, window_size):
    total = []
    window = window_size
    new_length = 0
    for i in range(input_tensor.size(0)):
        one_trail = []
        for k in range(input_tensor.size(1)):
            one_channel = []
            for y in range(input_tensor.size(2)):
                if y >= window:
                    # Use PyTorch operations for efficiency
                    window_slice = input_tensor[i, k, y-window:y]
                    avg = torch.mean(window_slice)
                    one_channel.append(avg.item())  # Convert back to Python scalar
            one_trail.append(one_channel)
            new_length = len(one_channel)
        total.append(one_trail)

    total_tensor = torch.tensor(total, dtype=input_tensor.dtype, device=input_tensor.device)
    return total_tensor, new_length

# %%
move_right_filtered = []
move_left_filtered = []

for subject in range(len(move_left)):
    left_filtered, new_timesteps = filter(move_left[subject], 32)
    move_left_filtered.append(left_filtered)

for subject in range(len(move_right)):
    right_filtered, new_timesteps = filter(move_right[subject], 32)
    move_right_filtered.append(right_filtered)

# %%
move_left_cpu_filtered = torch.tensor(move_left_filtered[20][1][1]).cpu()

plt.plot(move_left_cpu_filtered)
plt.ylabel('one trail of unscaled filtered signal')
plt.show()

# %%
def reshape(input_tensor):
    output_tensor = []
    for i in range(input_tensor.size(0)):
        each_trail = []
        before_trans = input_tensor[i].cpu().detach().numpy()
        transposed_tensor = torch.tensor(before_trans.transpose(), dtype=input_tensor.dtype, device=input_tensor.device)
        output_tensor.append(transposed_tensor)
    return output_tensor

# %%
move_right_reshaped = []
move_left_reshaped = []

for subject in range(len(move_left_filtered)):
    left_reshaped = reshape(move_left_filtered[subject])
    move_left_reshaped.append(left_reshaped)

for subject in range(len(move_right_filtered)):
    right_reshaped = reshape(move_right_filtered[subject])
    move_right_reshaped.append(right_reshaped)

# %%
trail01 = move_left_reshaped[19][0].cpu()
trail05 = move_left_reshaped[19][4].cpu()
trail10 = move_left_reshaped[19][9].cpu()
trail15 = move_left_reshaped[19][14].cpu()
plt.plot(trail01)
plt.title('Left Trial # 1 from subject 20')
plt.xlabel('Time')
plt.ylabel('non normaized Mag')
# plt.show()
plt.plot(trail05)
plt.title('Left Trial # 5 from subject 20')
plt.xlabel('Time')
plt.ylabel('not normaized Mag')
# plt.show()
plt.plot(trail10)
plt.title('Left Trial # 10 from subject 20')
plt.xlabel('Time')
plt.ylabel('not normaized Mag')
# plt.show()
plt.plot(trail15)
plt.title('Left Trial # 15 from subject 20')
plt.xlabel('Time')
plt.ylabel('not normaized Mag')
plt.show()

# %%
def normalize(input_data):
    output_tensor = []
    device = input_data[0].device
    for i in range(len(input_data)):
        scaler = StandardScaler()
        numpy_data = input_data[i].cpu().detach().numpy()
        scaler.fit(numpy_data)
        scaled_data = torch.tensor(scaler.transform(numpy_data), device=device)
        output_tensor.append(scaled_data)
    return output_tensor

# %%
move_right_normalized = []
move_left_normalized = []

for subject in range(len(move_left_reshaped)):
    left_normalized = normalize(move_left_reshaped[subject])
    move_left_normalized.append(left_normalized)

for subject in range(len(move_right_reshaped)):
    right_normalized = normalize(move_right_reshaped[subject])
    move_right_normalized.append(right_normalized)

# %%
ntrail01 = move_left_normalized[19][0].cpu()
ntrail05 = move_left_normalized[19][4].cpu()
ntrail10 = move_left_normalized[19][9].cpu()
ntrail15 = move_left_normalized[19][14].cpu()
plt.plot(ntrail01)
plt.title('Left Trial # 1 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
# plt.show()
plt.plot(ntrail05)
plt.title('Left Trial # 5 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
# plt.show()
plt.plot(ntrail10)
plt.title('Left Trial # 10 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
# plt.show()
plt.plot(ntrail15)
plt.title('Left Trial # 15 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
plt.show()

# %%
label = []
X = []
for i in range(len(move_left_normalized)):
    label.append([0]) # left - class 0
    X.append(move_left_normalized[i])
for y in range(len(move_right_normalized)):
    label.append([1]) # right - class 1
    X.append(move_right_normalized[y])

#shuffle arrays for randomness:
import random
temp = list(zip(X, label))
random.shuffle(temp)
X, label = zip(*temp)

# %% [markdown]
# Transfer into numpy array

# %%
label = np.array(label)
X = np.array([item[0].cpu().detach().numpy() for item in X])
X[0][0]

# %%
import math as math
element_num = len(X)
train_index = element_num * 0.8 #choose 80% for training and 20% for validation
train_index = math.floor(train_index)
scaled_X = np.array(normalize(torch.tensor(X)))
train_X = scaled_X[:train_index]
train_label = label[:train_index]
test_X = scaled_X[train_index:]
test_label = label[train_index:]

# %%
plt.plot(scaled_X[8])
plt.ylabel('one trial of scaled signal')
plt.show()

# %% [markdown]
# ### **Build the neural network**
# #### **K-fold Cross Validation**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Input
import keras
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=8, shuffle=True, random_state=seed)
cvscores = []
# code for building an LSTM with 100 neurons and dropout. Runs for 50 epochs
time_steps = 1536
n_features = 16

device = '/gpu:0'
for train, test in kfold.split(X, label):

    # val_data = (X[test], label[test])
    with tf.device(device):
      model = Sequential()
      model.add(Conv1D(filters=200,
                      kernel_size=75,
                      strides=1,
                      activation='relu',
                      padding='same'))
      model.add(Dropout(0.5))
      model.add(Conv1D(filters=200,
                      kernel_size=75,
                      strides=1,
                      activation='relu',
                      padding='same'))
      model.add(Dropout(0.4))
      model.add(MaxPooling1D(4))
      model.add(Conv1D(75, 75, activation='relu'))
      model.add(GlobalAveragePooling1D())
      model.add(Dropout(0.4))
      model.add(Dense(1, activation='sigmoid'))
      sgd = keras.optimizers.SGD(0.002, 0.9, False)
      model.compile(loss='binary_crossentropy',
                    optimizer=sgd,
                    metrics=['accuracy'])
      rnn = model.fit(X[train], label[train], batch_size=16, epochs=50, verbose=0)
      scores = model.evaluate(X[test], label[test], verbose=0)
      print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
      cvscores.append(scores[1] * 100)
print('%.2f%% (+/- %.2f%%)' % (np.mean(cvscores), np.std(cvscores)))
# Out:
# accuracy: 61.54%
# accuracy: 23.08%
# accuracy: 46.15%
# accuracy: 53.85%
# accuracy: 69.23%
# accuracy: 46.15%
# accuracy: 53.85%
# accuracy: 61.54%
# 51.92% (+/- 13.18%)

# %% [markdown]
# ## **Model Import**
# ### **LSTM**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D
from keras.layers import Input
import warnings
warnings.filterwarnings('ignore')

# code for building an LSTM with 100 neurons and dropout. Runs for 50 epochs
time_steps = new_timesteps
n_features = 16
device = '/gpu:0'
# write validation data into a tuple:
val_data = (test_X, test_label)
with tf.device(device):
  model = Sequential()
  model.add(Conv1D(filters=32,
                   kernel_size=32,
                   strides=1,
                   activation='relu',
                   padding='same',
                   input_shape=(time_steps, n_features)))
  model.add(LSTM(75, return_sequences=True, input_shape=(time_steps, n_features)))
  model.add(Dropout(0.2))
  model.add(LSTM(75, return_sequences=True))
  model.add(Dropout(0.2))
  model.add(LSTM(50, return_sequences=True))
  model.add(Dropout(0.2))
  model.add(LSTM(20, return_sequences=False))
  model.add(Dropout(0.2))
  model.add(Dense(1, activation='sigmoid'))
  # sgd = keras.optimizers.SGD(0.01, 0.0, False)
  model.summary()
  model.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  rnn = model.fit(train_X, train_label, batch_size=32, epochs=50, validation_data=val_data)
# score = model.evaluate(test_X, test_label)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_57 (Conv1D)          (None, 1504, 32)          16416
#
#  lstm_24 (LSTM)              (None, 1504, 75)          32400
#
#  dropout_75 (Dropout)        (None, 1504, 75)          0
#
#  lstm_25 (LSTM)              (None, 1504, 75)          45300
#
#  dropout_76 (Dropout)        (None, 1504, 75)          0
#
#  lstm_26 (LSTM)              (None, 1504, 50)          25200
#
#  dropout_77 (Dropout)        (None, 1504, 50)          0
#
#  lstm_27 (LSTM)              (None, 20)                5680
#
#  dropout_78 (Dropout)        (None, 20)                0
#
#  dense_23 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 125017 (488.35 KB)
# Trainable params: 125017 (488.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 3/3 [==============================] - 10s 955ms/step - loss: 0.7156 - accuracy: 0.4940 - val_loss: 0.8100 - val_accuracy: 0.2857
# Epoch 2/50
# 3/3 [==============================] - 1s 236ms/step - loss: 0.6542 - accuracy: 0.6386 - val_loss: 0.7796 - val_accuracy: 0.2857
# Epoch 3/50
# 3/3 [==============================] - 1s 192ms/step - loss: 0.6171 - accuracy: 0.7229 - val_loss: 0.8289 - val_accuracy: 0.3333
# Epoch 4/50
# 3/3 [==============================] - 1s 196ms/step - loss: 0.5679 - accuracy: 0.7349 - val_loss: 0.9620 - val_accuracy: 0.2857
# Epoch 5/50
# 3/3 [==============================] - 1s 192ms/step - loss: 0.5029 - accuracy: 0.7952 - val_loss: 1.0420 - val_accuracy: 0.2857
# Epoch 6/50
# 3/3 [==============================] - 1s 201ms/step - loss: 0.4497 - accuracy: 0.8554 - val_loss: 1.1178 - val_accuracy: 0.2857
# Epoch 7/50
# 3/3 [==============================] - 1s 272ms/step - loss: 0.3521 - accuracy: 0.8916 - val_loss: 1.2192 - val_accuracy: 0.3333
# Epoch 8/50
# 3/3 [==============================] - 1s 269ms/step - loss: 0.2730 - accuracy: 0.9277 - val_loss: 1.2568 - val_accuracy: 0.3810
# Epoch 9/50
# 3/3 [==============================] - 1s 274ms/step - loss: 0.2304 - accuracy: 0.9398 - val_loss: 1.3312 - val_accuracy: 0.3810
# Epoch 10/50
# 3/3 [==============================] - 1s 225ms/step - loss: 0.1979 - accuracy: 0.9639 - val_loss: 1.3369 - val_accuracy: 0.4286
# Epoch 11/50
# 3/3 [==============================] - 1s 191ms/step - loss: 0.2154 - accuracy: 0.9398 - val_loss: 1.3478 - val_accuracy: 0.4762
# Epoch 12/50
# 3/3 [==============================] - 1s 193ms/step - loss: 0.1434 - accuracy: 0.9759 - val_loss: 1.5002 - val_accuracy: 0.4286
# Epoch 13/50
# 3/3 [==============================] - 1s 196ms/step - loss: 0.1273 - accuracy: 0.9759 - val_loss: 1.4691 - val_accuracy: 0.3810
# Epoch 14/50
# 3/3 [==============================] - 1s 234ms/step - loss: 0.1935 - accuracy: 0.9398 - val_loss: 1.6660 - val_accuracy: 0.3810
# Epoch 15/50
# 3/3 [==============================] - 1s 193ms/step - loss: 0.1398 - accuracy: 0.9759 - val_loss: 1.6599 - val_accuracy: 0.3810
# Epoch 16/50
# 3/3 [==============================] - 1s 193ms/step - loss: 0.1747 - accuracy: 0.9518 - val_loss: 1.5915 - val_accuracy: 0.4762
# Epoch 17/50
# 3/3 [==============================] - 1s 194ms/step - loss: 0.1494 - accuracy: 0.9639 - val_loss: 1.5489 - val_accuracy: 0.4286
# Epoch 18/50
# 3/3 [==============================] - 1s 195ms/step - loss: 0.1638 - accuracy: 0.9639 - val_loss: 1.5249 - val_accuracy: 0.4762
# Epoch 19/50
# 3/3 [==============================] - 1s 194ms/step - loss: 0.1776 - accuracy: 0.9639 - val_loss: 1.6623 - val_accuracy: 0.4762
# Epoch 20/50
# 3/3 [==============================] - 1s 193ms/step - loss: 0.1850 - accuracy: 0.9518 - val_loss: 1.6513 - val_accuracy: 0.4762
# Epoch 21/50
# 3/3 [==============================] - 1s 192ms/step - loss: 0.1240 - accuracy: 0.9759 - val_loss: 1.7273 - val_accuracy: 0.4286
# Epoch 22/50
# 3/3 [==============================] - 1s 191ms/step - loss: 0.1529 - accuracy: 0.9518 - val_loss: 1.5914 - val_accuracy: 0.4762
# Epoch 23/50
# 3/3 [==============================] - 1s 191ms/step - loss: 0.1803 - accuracy: 0.9518 - val_loss: 1.6919 - val_accuracy: 0.4762
# Epoch 24/50
# 3/3 [==============================] - 1s 191ms/step - loss: 0.1727 - accuracy: 0.9518 - val_loss: 2.1648 - val_accuracy: 0.3333
# Epoch 25/50
# 3/3 [==============================] - 1s 230ms/step - loss: 0.1980 - accuracy: 0.9518 - val_loss: 2.0939 - val_accuracy: 0.3810
# Epoch 26/50
# 3/3 [==============================] - 1s 200ms/step - loss: 0.2545 - accuracy: 0.9277 - val_loss: 2.3149 - val_accuracy: 0.2857
# Epoch 27/50
# 3/3 [==============================] - 1s 192ms/step - loss: 0.2487 - accuracy: 0.9277 - val_loss: 2.2575 - val_accuracy: 0.2857
# Epoch 28/50
# 3/3 [==============================] - 1s 241ms/step - loss: 0.3063 - accuracy: 0.9036 - val_loss: 2.2102 - val_accuracy: 0.2381
# Epoch 29/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.2855 - accuracy: 0.9036 - val_loss: 2.0646 - val_accuracy: 0.2381
# Epoch 30/50
# 3/3 [==============================] - 1s 274ms/step - loss: 0.1584 - accuracy: 0.9639 - val_loss: 1.7234 - val_accuracy: 0.3333
# Epoch 31/50
# 3/3 [==============================] - 1s 247ms/step - loss: 0.1858 - accuracy: 0.9639 - val_loss: 1.7356 - val_accuracy: 0.4286
# Epoch 32/50
# 3/3 [==============================] - 1s 215ms/step - loss: 0.2805 - accuracy: 0.9157 - val_loss: 1.7146 - val_accuracy: 0.4286
# Epoch 33/50
# 3/3 [==============================] - 1s 191ms/step - loss: 0.1907 - accuracy: 0.9518 - val_loss: 1.6666 - val_accuracy: 0.3810
# Epoch 34/50
# 3/3 [==============================] - 1s 230ms/step - loss: 0.2221 - accuracy: 0.9398 - val_loss: 1.8317 - val_accuracy: 0.2857
# Epoch 35/50
# 3/3 [==============================] - 1s 194ms/step - loss: 0.1415 - accuracy: 0.9639 - val_loss: 2.0655 - val_accuracy: 0.2857
# Epoch 36/50
# 3/3 [==============================] - 1s 192ms/step - loss: 0.1281 - accuracy: 0.9759 - val_loss: 2.1449 - val_accuracy: 0.2857
# Epoch 37/50
# 3/3 [==============================] - 1s 197ms/step - loss: 0.1327 - accuracy: 0.9639 - val_loss: 2.1955 - val_accuracy: 0.2857
# Epoch 38/50
# 3/3 [==============================] - 1s 194ms/step - loss: 0.1168 - accuracy: 0.9759 - val_loss: 2.2394 - val_accuracy: 0.2857
# Epoch 39/50
# 3/3 [==============================] - 1s 231ms/step - loss: 0.1175 - accuracy: 0.9759 - val_loss: 2.2872 - val_accuracy: 0.2857
# Epoch 40/50
# 3/3 [==============================] - 1s 193ms/step - loss: 0.1092 - accuracy: 0.9759 - val_loss: 2.3301 - val_accuracy: 0.2857
# Epoch 41/50
# 3/3 [==============================] - 1s 232ms/step - loss: 0.0987 - accuracy: 0.9759 - val_loss: 2.3684 - val_accuracy: 0.2857
# Epoch 42/50
# 3/3 [==============================] - 1s 193ms/step - loss: 0.1021 - accuracy: 0.9759 - val_loss: 2.4107 - val_accuracy: 0.2857
# Epoch 43/50
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0914 - accuracy: 0.9759 - val_loss: 2.4287 - val_accuracy: 0.2857
# Epoch 44/50
# 3/3 [==============================] - 1s 230ms/step - loss: 0.1024 - accuracy: 0.9759 - val_loss: 2.4469 - val_accuracy: 0.2857
# Epoch 45/50
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0938 - accuracy: 0.9759 - val_loss: 2.4626 - val_accuracy: 0.2857
# Epoch 46/50
# 3/3 [==============================] - 1s 196ms/step - loss: 0.0946 - accuracy: 0.9759 - val_loss: 2.5028 - val_accuracy: 0.2857
# Epoch 47/50
# 3/3 [==============================] - 1s 193ms/step - loss: 0.0885 - accuracy: 0.9759 - val_loss: 2.5736 - val_accuracy: 0.2857
# Epoch 48/50
# 3/3 [==============================] - 1s 194ms/step - loss: 0.0812 - accuracy: 0.9759 - val_loss: 2.6561 - val_accuracy: 0.2857
# Epoch 49/50
# 3/3 [==============================] - 1s 228ms/step - loss: 0.0763 - accuracy: 0.9759 - val_loss: 2.7262 - val_accuracy: 0.2857
# Epoch 50/50
# 3/3 [==============================] - 1s 242ms/step - loss: 0.0692 - accuracy: 0.9759 - val_loss: 2.7453 - val_accuracy: 0.2857

# %%
model.save(os.path.join(path_to_model, 'lstm.pth'))

# %%
#Visualize Result
# Plot training & validation accuracy values
plt.plot(rnn.history['accuracy'])
plt.plot(rnn.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(rnn.history['loss'])
plt.plot(rnn.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### **CNN**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Input
import keras
# time_steps = new_timesteps
time_steps = 1536
n_features = 16
#write validation data into a tuple:
val_data = (test_X, test_label)
device = '/gpu:0'
with tf.device(device):
  model = Sequential()
  model.add(Conv1D(filters=100, #200 get 0.6955
                  kernel_size=50,
                  strides=1,
                  activation='relu',
                  padding='same'))
  model.add(Dropout(0.6))
  model.add(Conv1D(filters=100,
                  kernel_size=50,
                  strides=1,
                  activation='relu',
                  padding='same'))
  model.add(Dropout(0.5))
  model.add(MaxPooling1D(4))
  model.add(Conv1D(50, 50, activation='relu'))
  model.add(GlobalAveragePooling1D())
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))
  sgd = keras.optimizers.SGD(0.002, 0.9, False)
  model.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  rnn = model.fit(train_X, train_label, batch_size=2, epochs=50, validation_data=val_data) #batch size=16 for 11 subjects' data
  # print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
# score = model.evaluate(test_X, test_label)
# Out:
# Epoch 1/50
# 42/42 [==============================] - 2s 16ms/step - loss: 1.1881 - accuracy: 0.5422 - val_loss: 0.6930 - val_accuracy: 0.5238
# Epoch 2/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6934 - accuracy: 0.5783 - val_loss: 0.6918 - val_accuracy: 0.5238
# Epoch 3/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.7302 - accuracy: 0.6024 - val_loss: 0.7036 - val_accuracy: 0.4286
# Epoch 4/50
# 42/42 [==============================] - 0s 8ms/step - loss: 1.0149 - accuracy: 0.4337 - val_loss: 0.6901 - val_accuracy: 0.7143
# Epoch 5/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6950 - accuracy: 0.3735 - val_loss: 0.6932 - val_accuracy: 0.4762
# Epoch 6/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6932 - accuracy: 0.4337 - val_loss: 0.6931 - val_accuracy: 0.5238
# Epoch 7/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6932 - accuracy: 0.4819 - val_loss: 0.6932 - val_accuracy: 0.4762
# Epoch 8/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6848 - accuracy: 0.5181 - val_loss: 0.7060 - val_accuracy: 0.3810
# Epoch 9/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.7771 - accuracy: 0.4337 - val_loss: 0.6932 - val_accuracy: 0.4762
# Epoch 10/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6928 - accuracy: 0.4337 - val_loss: 0.6931 - val_accuracy: 0.5238
# Epoch 11/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6898 - accuracy: 0.4578 - val_loss: 0.6932 - val_accuracy: 0.4762
# Epoch 12/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6854 - accuracy: 0.4699 - val_loss: 0.6932 - val_accuracy: 0.4762
# Epoch 13/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6847 - accuracy: 0.4699 - val_loss: 0.6931 - val_accuracy: 0.5238
# Epoch 14/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6899 - accuracy: 0.4578 - val_loss: 0.6930 - val_accuracy: 0.5238
# Epoch 15/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6844 - accuracy: 0.5060 - val_loss: 0.6931 - val_accuracy: 0.5238
# Epoch 16/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.9540 - accuracy: 0.5060 - val_loss: 0.6930 - val_accuracy: 0.5238
# Epoch 17/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6839 - accuracy: 0.5422 - val_loss: 0.6930 - val_accuracy: 0.5238
# Epoch 18/50
# 42/42 [==============================] - 0s 9ms/step - loss: 1.5819 - accuracy: 0.5542 - val_loss: 0.6928 - val_accuracy: 0.5238
# Epoch 19/50
# 42/42 [==============================] - 0s 9ms/step - loss: 1.5027 - accuracy: 0.6024 - val_loss: 0.6927 - val_accuracy: 0.5238
# Epoch 20/50
# 42/42 [==============================] - 0s 11ms/step - loss: 0.6934 - accuracy: 0.4940 - val_loss: 0.6927 - val_accuracy: 0.5238
# Epoch 21/50
# 42/42 [==============================] - 0s 10ms/step - loss: 0.6899 - accuracy: 0.5181 - val_loss: 0.6928 - val_accuracy: 0.5238
# Epoch 22/50
# 42/42 [==============================] - 0s 11ms/step - loss: 0.6702 - accuracy: 0.5422 - val_loss: 0.6928 - val_accuracy: 0.5238
# Epoch 23/50
# 42/42 [==============================] - 0s 11ms/step - loss: 0.6642 - accuracy: 0.5663 - val_loss: 0.6927 - val_accuracy: 0.5238
# Epoch 24/50
# 42/42 [==============================] - 0s 10ms/step - loss: 0.6968 - accuracy: 0.5542 - val_loss: 0.6927 - val_accuracy: 0.5238
# Epoch 25/50
# 42/42 [==============================] - 0s 11ms/step - loss: 0.6799 - accuracy: 0.5663 - val_loss: 0.6929 - val_accuracy: 0.5238
# Epoch 26/50
# 42/42 [==============================] - 0s 11ms/step - loss: 1.0503 - accuracy: 0.6747 - val_loss: 0.6967 - val_accuracy: 0.4762
# Epoch 27/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6449 - accuracy: 0.6386 - val_loss: 0.6935 - val_accuracy: 0.4762
# Epoch 28/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6619 - accuracy: 0.6265 - val_loss: 0.6924 - val_accuracy: 0.5238
# Epoch 29/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.7234 - accuracy: 0.5783 - val_loss: 0.6924 - val_accuracy: 0.5238
# Epoch 30/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6971 - accuracy: 0.5181 - val_loss: 0.6923 - val_accuracy: 0.5238
# Epoch 31/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6850 - accuracy: 0.5301 - val_loss: 0.6924 - val_accuracy: 0.5238
# Epoch 32/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6653 - accuracy: 0.5542 - val_loss: 0.6923 - val_accuracy: 0.5238
# Epoch 33/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6600 - accuracy: 0.5422 - val_loss: 0.6923 - val_accuracy: 0.5238
# Epoch 34/50
# 42/42 [==============================] - 0s 9ms/step - loss: 1.0495 - accuracy: 0.6024 - val_loss: 0.6923 - val_accuracy: 0.5238
# Epoch 35/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6482 - accuracy: 0.5904 - val_loss: 0.6923 - val_accuracy: 0.5238
# Epoch 36/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6423 - accuracy: 0.5783 - val_loss: 0.6922 - val_accuracy: 0.5238
# Epoch 37/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6281 - accuracy: 0.5904 - val_loss: 0.6922 - val_accuracy: 0.5238
# Epoch 38/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6270 - accuracy: 0.6145 - val_loss: 0.6960 - val_accuracy: 0.4762
# Epoch 39/50
# 42/42 [==============================] - 0s 9ms/step - loss: 1.1491 - accuracy: 0.6506 - val_loss: 0.6921 - val_accuracy: 0.5238
# Epoch 40/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6602 - accuracy: 0.5663 - val_loss: 0.6921 - val_accuracy: 0.5238
# Epoch 41/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6513 - accuracy: 0.5663 - val_loss: 0.6921 - val_accuracy: 0.5238
# Epoch 42/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6440 - accuracy: 0.5663 - val_loss: 0.6921 - val_accuracy: 0.5238
# Epoch 43/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6409 - accuracy: 0.5783 - val_loss: 0.6933 - val_accuracy: 0.5238
# Epoch 44/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6387 - accuracy: 0.5663 - val_loss: 0.6921 - val_accuracy: 0.5238
# Epoch 45/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6323 - accuracy: 0.5904 - val_loss: 0.6927 - val_accuracy: 0.5238
# Epoch 46/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6278 - accuracy: 0.5904 - val_loss: 0.6957 - val_accuracy: 0.4762
# Epoch 47/50
# 42/42 [==============================] - 0s 9ms/step - loss: 0.6402 - accuracy: 0.6024 - val_loss: 0.6920 - val_accuracy: 0.5238
# Epoch 48/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6467 - accuracy: 0.5783 - val_loss: 0.6920 - val_accuracy: 0.5238
# Epoch 49/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6328 - accuracy: 0.5783 - val_loss: 0.6957 - val_accuracy: 0.4762
# Epoch 50/50
# 42/42 [==============================] - 0s 8ms/step - loss: 0.6272 - accuracy: 0.5783 - val_loss: 0.6922 - val_accuracy: 0.5238

# %%
model.save(os.path.join(path_to_model, 'cnn.pth'))

# %%
#Visualize Result
# Plot training & validation accuracy values
plt.plot(rnn.history['accuracy'])
plt.plot(rnn.history['val_accuracy'])
plt.title('1D-CNN Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(rnn.history['loss'])
plt.plot(rnn.history['val_loss'])
plt.title('CNN Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('CNN Model Loss')
plt.show()

# %%
print(rnn.history['val_accuracy'][49])f
# Out:
# 0.523809552192688

# %% [markdown]
# ### **Visualize the Results**

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')
