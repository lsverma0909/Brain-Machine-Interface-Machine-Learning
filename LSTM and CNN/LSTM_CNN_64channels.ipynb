# %% [markdown]
# # **Senior Design Project - Brain Machine Interface**
#
#
#
# ### Krithik Parvataneni, Lisa Verma, Tsenbujin Tsendjav, Wencan Yang

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_to_mat = '/content/drive/Shared drives/EEC174AY Group 8/Dataset/mat_data'
path_to_txt = '/content/drive/Shared drives/EEC174AY Group 8/Dataset/txt_data'
path_to_model = '/content/drive/Shared drives/EEC174AY Group 8/models/'

# %% [markdown]
# ## **All imports used**

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import os
import pandas as pd
import gc
import torch.utils.data as data
import torchvision.datasets as datasets
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D
from keras.layers import Input
from sklearn.preprocessing import StandardScaler
import torch
import numpy as np
import keras

# %% [markdown]
# ## **Load the dataset**

# %% [markdown]
# ## **Data preprocessing**
# ### **Data loader:**

# %%
class DataSet(data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.files = [file.path for file in os.scandir(self.root_dir)]
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        file_path = self.files[idx]
        mat_data = sio.loadmat(file_path)

        all_data = []
        all_data.append(mat_data)

        return all_data

# %%
# 4 channels
class get_data():

    def __init__(self, mat_input, device):
        self.mat_input = mat_input
        self.device = device

    def get_movement(self, channels=None):
        movement_left = []
        movement_right = []
        movement_event = []
        sliced_left = []
        sliced_right = []
        index = []
        movement_event = self.mat_input['eeg']['movement_event'][0][0][0]
        if channels == None:
          channels = [9,11,44,48]
        # get raw dataset
        for i in channels:
            movement_left.append(self.mat_input['eeg']['movement_left'][0][0][i])
            movement_right.append(self.mat_input['eeg']['movement_right'][0][0][i])
        #get onset (starting pt) of movement_event:
        for q in range(len(movement_event)):
            if movement_event[q] == 1:
                  index.append(q)
        #slice movement_left and right to only keep active region:
        for x in range(len(index)):
            temp_left = []
            temp_right = []
            for j in range(len(movement_left)):
                start_index = index[x]
                end_index = start_index + 1536 #three seconds for a period
                temp_left.append(movement_left[j][start_index:end_index])
                temp_right.append(movement_right[j][start_index:end_index])
            sliced_left.append(temp_left)
            sliced_right.append(temp_right)

        sliced_left_tensor = torch.tensor(np.array(sliced_left), device=self.device)
        sliced_right_tensor = torch.tensor(np.array(sliced_right), device=self.device)
        index_tensor = torch.tensor(np.array(index), device=self.device)

        return sliced_left_tensor, index_tensor, sliced_right_tensor

# %%
mat_data = DataSet(path_to_mat)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

move_left = []
move_right = []
move_idx = []
for subject in range(len(mat_data)):
  left = []
  right = []
  index = []
  left, idx, right = get_data(mat_data[subject][0], device).get_movement()
  move_left.append(left)
  move_right.append(right)
  move_idx.append(idx)

# %%
move_left_cpu = move_left[20][1][1].cpu()
# Convert tensor to numpy array
left_numpy = move_left_cpu.detach().numpy()

plt.plot(left_numpy)
plt.ylabel('one trial of unscaled signal')
plt.show()

# %%
def filter(input_tensor, window_size):
    total = []
    window = window_size
    new_length = 0
    for i in range(input_tensor.size(0)):
        one_trail = []
        for k in range(input_tensor.size(1)):
            one_channel = []
            for y in range(input_tensor.size(2)):
                if y >= window:
                    # Use PyTorch operations for efficiency
                    window_slice = input_tensor[i, k, y-window:y]
                    avg = torch.mean(window_slice)
                    one_channel.append(avg.item())  # Convert back to Python scalar
            one_trail.append(one_channel)
            new_length = len(one_channel)
        total.append(one_trail)

    total_tensor = torch.tensor(total, dtype=input_tensor.dtype, device=input_tensor.device)
    return total_tensor, new_length

move_right_filtered = []
move_left_filtered = []

for subject in range(len(move_left)):
    left_filtered, new_timesteps = filter(move_left[subject], 32)
    move_left_filtered.append(left_filtered)

for subject in range(len(move_right)):
    right_filtered, new_timesteps = filter(move_right[subject], 32)
    move_right_filtered.append(right_filtered)

# %%
move_left_cpu_filtered = torch.tensor(move_left_filtered[20][1][1]).cpu()

plt.plot(move_left_cpu_filtered)
plt.ylabel('one trial of unscaled filtered signal')
plt.show()
# Out:
# <ipython-input-15-cda98aac56eb>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   move_left_cpu_filtered = torch.tensor(move_left_filtered[20][1][1]).cpu()

# %%
def reshape(input_tensor):
    output_tensor = []
    for i in range(input_tensor.size(0)):
        each_trail = []
        before_trans = input_tensor[i].cpu().detach().numpy()
        transposed_tensor = torch.tensor(before_trans.transpose(), dtype=input_tensor.dtype, device=input_tensor.device)
        output_tensor.append(transposed_tensor)
    return output_tensor

# %%
move_right_reshaped = []
move_left_reshaped = []

for subject in range(len(move_left_filtered)):
    left_reshaped = reshape(move_left_filtered[subject])
    move_left_reshaped.append(left_reshaped)

for subject in range(len(move_right_filtered)):
    right_reshaped = reshape(move_right_filtered[subject])
    move_right_reshaped.append(right_reshaped)

# %%
trail01 = move_left_reshaped[19][0].cpu()
trail05 = move_left_reshaped[19][4].cpu()
trail10 = move_left_reshaped[19][9].cpu()
trail15 = move_left_reshaped[19][14].cpu()
plt.plot(trail01)
plt.title('Left Trial # 1 from subject 20')
plt.xlabel('Time')
plt.ylabel('non normaized Mag')
# plt.show()
plt.plot(trail05)
plt.title('Left Trial # 5 from subject 20')
plt.xlabel('Time')
plt.ylabel('not normaized Mag')
# plt.show()
plt.plot(trail10)
plt.title('Left Trial # 10 from subject 20')
plt.xlabel('Time')
plt.ylabel('not normaized Mag')
# plt.show()
plt.plot(trail15)
plt.title('Left Trial # 15 from subject 20')
plt.xlabel('Time')
plt.ylabel('not normaized Mag')
plt.show()

# %%
def normalize(input_data):
    output_tensor = []
    device = input_data[0].device
    for i in range(len(input_data)):
        scaler = StandardScaler()
        numpy_data = input_data[i].cpu().detach().numpy()
        scaler.fit(numpy_data)
        scaled_data = torch.tensor(scaler.transform(numpy_data), device=device)
        output_tensor.append(scaled_data)
    return output_tensor

# %%
move_right_normalized = []
move_left_normalized = []

for subject in range(len(move_left_reshaped)):
    left_normalized = normalize(move_left_reshaped[subject])
    move_left_normalized.append(left_normalized)

for subject in range(len(move_right_reshaped)):
    right_normalized = normalize(move_right_reshaped[subject])
    move_right_normalized.append(right_normalized)

# %%
ntrail01 = move_left_normalized[19][0].cpu()
ntrail05 = move_left_normalized[19][4].cpu()
ntrail10 = move_left_normalized[19][9].cpu()
ntrail15 = move_left_normalized[19][14].cpu()
plt.plot(ntrail01)
plt.title('Left Trial # 1 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
# plt.show()
plt.plot(ntrail05)
plt.title('Left Trial # 5 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
# plt.show()
plt.plot(ntrail10)
plt.title('Left Trial # 10 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
# plt.show()
plt.plot(ntrail15)
plt.title('Left Trial # 15 from subject 20')
plt.xlabel('Time')
plt.ylabel('normaized Mag')
plt.show()

# %%
label = []
X = []
for i in range(len(move_left_normalized)):
    label.append([0]) # left - class 0
    X.append(move_left_normalized[i])
for y in range(len(move_right_normalized)):
    label.append([1]) # right - class 1
    X.append(move_right_normalized[y])

#shuffle arrays for randomness:
import random
temp = list(zip(X, label))
random.shuffle(temp)
X, label = zip(*temp)
# Out:
# 104
# 104

# %% [markdown]
# Transfer into numpy array

# %%
label = np.array(label)
X = np.array([item[0].cpu().detach().numpy() for item in X])
X[0][0]
# Out:
# array([ 1.2144432,  2.1484537, -0.9441309,  0.6205043], dtype=float32)

# %%
import math as math
element_num = len(X)
train_index = element_num * 0.8 #choose 80% for training and 20% for validation
train_index = math.floor(train_index)
scaled_X = np.array(normalize(torch.tensor(X)))
train_X = scaled_X[:train_index]
train_label = label[:train_index]
test_X = scaled_X[train_index:]
test_label = label[train_index:]

# %%
plt.plot(scaled_X[8])
plt.ylabel('one trail of scaled signal')
plt.show()

# %% [markdown]
# ### **Build the neural network**
# #### **K-fold Cross Validation**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Input
import keras
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
import warnings
warnings.filterwarnings('ignore')
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# define 10-fold cross validation test harness
kfold = StratifiedKFold(n_splits=8, shuffle=True, random_state=seed)
cvscores = []
# code for building an LSTM with 100 neurons and dropout. Runs for 50 epochs
time_steps = 1536 # change it if filtered
n_features = 4

device = '/gpu:0'
for train, test in kfold.split(X, label):

    # val_data = (X[test], label[test])
    with tf.device(device):
      model = Sequential()
      model.add(Conv1D(filters=200, #200 get 0.6955
                      kernel_size=75,
                      strides=1,
                      activation='relu',
                      padding='same'))
      model.add(Dropout(0.5))
      model.add(Conv1D(filters=200,
                      kernel_size=75,
                      strides=1,
                      activation='relu',
                      padding='same'))
      model.add(Dropout(0.4))
      model.add(MaxPooling1D(4))
      model.add(Conv1D(75, 75, activation='relu'))
      model.add(GlobalAveragePooling1D())
      model.add(Dropout(0.4))
      model.add(Dense(1, activation='sigmoid'))
      sgd = keras.optimizers.SGD(0.002, 0.9, False) 
      model.compile(loss='binary_crossentropy',
                    # optimizer='adam',
                    optimizer=sgd,
                    metrics=['accuracy'])
      rnn = model.fit(X[train], label[train], batch_size=16, epochs=50, verbose=0)
      scores = model.evaluate(X[test], label[test], verbose=0)
      print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
      cvscores.append(scores[1] * 100)
print('%.2f%% (+/- %.2f%%)' % (np.mean(cvscores), np.std(cvscores)))

# %% [markdown]
# ## **Model Import**
# ### **LSTM**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D
from keras.layers import Input
import warnings
warnings.filterwarnings('ignore')

# code for building an LSTM with 100 neurons and dropout. Runs for 50 epochs
time_steps = new_timesteps # change with or without filter
n_features = 4
device = '/gpu:0'
# write validation data into a tuple:
val_data = (test_X, test_label)
with tf.device(device):
  model = Sequential()
  model.add(Conv1D(filters=32,
                   kernel_size=32,
                   strides=1,
                   activation='relu',
                   padding='same',
                   input_shape=(time_steps, n_features)))
  model.add(LSTM(75, return_sequences=True, input_shape=(time_steps, n_features)))
  model.add(Dropout(0.2))
  model.add(LSTM(75, return_sequences=True))
  model.add(Dropout(0.2))
  model.add(LSTM(50, return_sequences=True))
  model.add(Dropout(0.2))
  model.add(LSTM(20, return_sequences=False))
  model.add(Dropout(0.2))
  model.add(Dense(1, activation='sigmoid'))
  model.summary()
  model.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  rnn = model.fit(train_X, train_label, batch_size=32, epochs=50, validation_data=val_data)
# score = model.evaluate(test_X, test_label)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_39 (Conv1D)          (None, 1504, 32)          4128
#
#  lstm_24 (LSTM)              (None, 1504, 75)          32400
#
#  dropout_57 (Dropout)        (None, 1504, 75)          0
#
#  lstm_25 (LSTM)              (None, 1504, 75)          45300
#
#  dropout_58 (Dropout)        (None, 1504, 75)          0
#
#  lstm_26 (LSTM)              (None, 1504, 50)          25200
#
#  dropout_59 (Dropout)        (None, 1504, 50)          0
#
#  lstm_27 (LSTM)              (None, 20)                5680
#
#  dropout_60 (Dropout)        (None, 20)                0
#
#  dense_17 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 112729 (440.35 KB)
# Trainable params: 112729 (440.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 1/1 [==============================] - 8s 8s/step - loss: 0.6966 - accuracy: 0.4062 - val_loss: 0.6884 - val_accuracy: 0.5000
# Epoch 2/50
# 1/1 [==============================] - 0s 446ms/step - loss: 0.6879 - accuracy: 0.5312 - val_loss: 0.6939 - val_accuracy: 0.3750
# Epoch 3/50
# 1/1 [==============================] - 0s 249ms/step - loss: 0.6786 - accuracy: 0.5938 - val_loss: 0.6982 - val_accuracy: 0.3750
# Epoch 4/50
# 1/1 [==============================] - 0s 236ms/step - loss: 0.6606 - accuracy: 0.7188 - val_loss: 0.7025 - val_accuracy: 0.3750
# Epoch 5/50
# 1/1 [==============================] - 0s 231ms/step - loss: 0.6432 - accuracy: 0.6875 - val_loss: 0.7081 - val_accuracy: 0.3750
# Epoch 6/50
# 1/1 [==============================] - 0s 237ms/step - loss: 0.6497 - accuracy: 0.7188 - val_loss: 0.7142 - val_accuracy: 0.3750
# Epoch 7/50
# 1/1 [==============================] - 0s 319ms/step - loss: 0.6220 - accuracy: 0.7188 - val_loss: 0.7226 - val_accuracy: 0.3750
# Epoch 8/50
# 1/1 [==============================] - 0s 237ms/step - loss: 0.6114 - accuracy: 0.7500 - val_loss: 0.7299 - val_accuracy: 0.3750
# Epoch 9/50
# 1/1 [==============================] - 0s 231ms/step - loss: 0.5728 - accuracy: 0.7500 - val_loss: 0.7423 - val_accuracy: 0.3750
# Epoch 10/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.5395 - accuracy: 0.8125 - val_loss: 0.7682 - val_accuracy: 0.3750
# Epoch 11/50
# 1/1 [==============================] - 0s 243ms/step - loss: 0.5262 - accuracy: 0.8125 - val_loss: 0.8052 - val_accuracy: 0.3750
# Epoch 12/50
# 1/1 [==============================] - 0s 233ms/step - loss: 0.5061 - accuracy: 0.8438 - val_loss: 0.8504 - val_accuracy: 0.5000
# Epoch 13/50
# 1/1 [==============================] - 0s 231ms/step - loss: 0.4748 - accuracy: 0.8438 - val_loss: 0.8969 - val_accuracy: 0.5000
# Epoch 14/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.4789 - accuracy: 0.8438 - val_loss: 0.9314 - val_accuracy: 0.5000
# Epoch 15/50
# 1/1 [==============================] - 0s 237ms/step - loss: 0.4419 - accuracy: 0.8438 - val_loss: 0.9627 - val_accuracy: 0.5000
# Epoch 16/50
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3986 - accuracy: 0.8438 - val_loss: 1.0164 - val_accuracy: 0.5000
# Epoch 17/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.3775 - accuracy: 0.9062 - val_loss: 1.1458 - val_accuracy: 0.3750
# Epoch 18/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.4063 - accuracy: 0.8750 - val_loss: 1.1902 - val_accuracy: 0.3750
# Epoch 19/50
# 1/1 [==============================] - 0s 230ms/step - loss: 0.3620 - accuracy: 0.8750 - val_loss: 1.2322 - val_accuracy: 0.3750
# Epoch 20/50
# 1/1 [==============================] - 0s 240ms/step - loss: 0.3676 - accuracy: 0.9062 - val_loss: 1.2790 - val_accuracy: 0.3750
# Epoch 21/50
# 1/1 [==============================] - 0s 236ms/step - loss: 0.3207 - accuracy: 0.9062 - val_loss: 1.3325 - val_accuracy: 0.3750
# Epoch 22/50
# 1/1 [==============================] - 0s 231ms/step - loss: 0.4194 - accuracy: 0.8750 - val_loss: 1.3768 - val_accuracy: 0.3750
# Epoch 23/50
# 1/1 [==============================] - 0s 331ms/step - loss: 0.4129 - accuracy: 0.8750 - val_loss: 1.2323 - val_accuracy: 0.3750
# Epoch 24/50
# 1/1 [==============================] - 0s 368ms/step - loss: 0.4823 - accuracy: 0.7812 - val_loss: 1.4232 - val_accuracy: 0.3750
# Epoch 25/50
# 1/1 [==============================] - 0s 308ms/step - loss: 0.4472 - accuracy: 0.8750 - val_loss: 1.5538 - val_accuracy: 0.2500
# Epoch 26/50
# 1/1 [==============================] - 0s 307ms/step - loss: 0.4310 - accuracy: 0.8750 - val_loss: 1.5527 - val_accuracy: 0.2500
# Epoch 27/50
# 1/1 [==============================] - 0s 304ms/step - loss: 0.4391 - accuracy: 0.8750 - val_loss: 1.3609 - val_accuracy: 0.2500
# Epoch 28/50
# 1/1 [==============================] - 0s 368ms/step - loss: 0.3909 - accuracy: 0.8438 - val_loss: 1.2285 - val_accuracy: 0.3750
# Epoch 29/50
# 1/1 [==============================] - 0s 324ms/step - loss: 0.4318 - accuracy: 0.8750 - val_loss: 1.1767 - val_accuracy: 0.5000
# Epoch 30/50
# 1/1 [==============================] - 0s 389ms/step - loss: 0.3991 - accuracy: 0.8750 - val_loss: 1.2292 - val_accuracy: 0.3750
# Epoch 31/50
# 1/1 [==============================] - 0s 292ms/step - loss: 0.3856 - accuracy: 0.8750 - val_loss: 1.4983 - val_accuracy: 0.2500
# Epoch 32/50
# 1/1 [==============================] - 0s 230ms/step - loss: 0.4028 - accuracy: 0.8750 - val_loss: 1.5348 - val_accuracy: 0.2500
# Epoch 33/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.4104 - accuracy: 0.8750 - val_loss: 1.5434 - val_accuracy: 0.2500
# Epoch 34/50
# 1/1 [==============================] - 0s 243ms/step - loss: 0.3965 - accuracy: 0.8438 - val_loss: 1.4297 - val_accuracy: 0.3750
# Epoch 35/50
# 1/1 [==============================] - 0s 239ms/step - loss: 0.3876 - accuracy: 0.8750 - val_loss: 1.4111 - val_accuracy: 0.3750
# Epoch 36/50
# 1/1 [==============================] - 0s 233ms/step - loss: 0.3358 - accuracy: 0.8750 - val_loss: 1.4235 - val_accuracy: 0.3750
# Epoch 37/50
# 1/1 [==============================] - 0s 241ms/step - loss: 0.3077 - accuracy: 0.9062 - val_loss: 1.5824 - val_accuracy: 0.2500
# Epoch 38/50
# 1/1 [==============================] - 0s 248ms/step - loss: 0.3347 - accuracy: 0.9062 - val_loss: 1.6935 - val_accuracy: 0.2500
# Epoch 39/50
# 1/1 [==============================] - 0s 225ms/step - loss: 0.3141 - accuracy: 0.9062 - val_loss: 1.7104 - val_accuracy: 0.2500
# Epoch 40/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.3491 - accuracy: 0.8750 - val_loss: 1.3492 - val_accuracy: 0.3750
# Epoch 41/50
# 1/1 [==============================] - 0s 240ms/step - loss: 0.3269 - accuracy: 0.9062 - val_loss: 1.3197 - val_accuracy: 0.5000
# Epoch 42/50
# 1/1 [==============================] - 0s 233ms/step - loss: 0.2768 - accuracy: 0.9375 - val_loss: 1.4216 - val_accuracy: 0.3750
# Epoch 43/50
# 1/1 [==============================] - 0s 243ms/step - loss: 0.3415 - accuracy: 0.9062 - val_loss: 1.4084 - val_accuracy: 0.3750
# Epoch 44/50
# 1/1 [==============================] - 0s 231ms/step - loss: 0.2974 - accuracy: 0.8750 - val_loss: 1.2199 - val_accuracy: 0.5000
# Epoch 45/50
# 1/1 [==============================] - 0s 234ms/step - loss: 0.2316 - accuracy: 0.9375 - val_loss: 1.2268 - val_accuracy: 0.5000
# Epoch 46/50
# 1/1 [==============================] - 0s 244ms/step - loss: 0.2573 - accuracy: 0.9062 - val_loss: 1.2453 - val_accuracy: 0.5000
# Epoch 47/50
# 1/1 [==============================] - 0s 240ms/step - loss: 0.2570 - accuracy: 0.9375 - val_loss: 1.2676 - val_accuracy: 0.5000
# Epoch 48/50
# 1/1 [==============================] - 0s 233ms/step - loss: 0.2300 - accuracy: 0.9688 - val_loss: 1.2932 - val_accuracy: 0.3750
# Epoch 49/50
# 1/1 [==============================] - 0s 238ms/step - loss: 0.2408 - accuracy: 0.9375 - val_loss: 1.3194 - val_accuracy: 0.3750
# Epoch 50/50
# 1/1 [==============================] - 0s 246ms/step - loss: 0.2250 - accuracy: 0.9688 - val_loss: 1.3453 - val_accuracy: 0.3750

# %%
model.save(os.path.join(path_to_model, 'lstm.pth'))

# %%
#Visualize Result
# Plot training & validation accuracy values
plt.plot(rnn.history['accuracy'])
plt.plot(rnn.history['val_accuracy'])
plt.title('LSTM Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(rnn.history['loss'])
plt.plot(rnn.history['val_loss'])
plt.title('LSTM Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### **CNN**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Embedding
from keras.layers import LSTM
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D
from keras.layers import Input
import keras
# time_steps = new_timesteps
time_steps = 1536
n_features = 4
#write validation data into a tuple:
val_data = (test_X, test_label)
device = '/gpu:0'
with tf.device(device):
  model = Sequential()
  model.add(Conv1D(filters=100, #200 get 0.6955
                  kernel_size=50,
                  strides=1,
                  activation='relu',
                  padding='same'))
  model.add(Dropout(0.6))
  model.add(Conv1D(filters=100,
                  kernel_size=50,
                  strides=1,
                  activation='relu',
                  padding='same'))
  model.add(Dropout(0.5))
  model.add(MaxPooling1D(4))
  model.add(Conv1D(50, 50, activation='relu'))
  model.add(GlobalAveragePooling1D())
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))
  sgd = keras.optimizers.SGD(0.00020, 0.0, False) #0.0001 for combined dataset
  model.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy'])
  rnn = model.fit(train_X, train_label, batch_size=2, epochs=50, validation_data=val_data) #batch size=16 for 11 subjects' data
  # print('%s: %.2f%%' % (model.metrics_names[1], scores[1]*100))
# score = model.evaluate(test_X, test_label)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 3s 25ms/step - loss: 1.4370 - accuracy: 0.5000 - val_loss: 0.7228 - val_accuracy: 0.5000
# Epoch 2/50
# 16/16 [==============================] - 0s 13ms/step - loss: 0.7880 - accuracy: 0.5938 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 3/50
# 16/16 [==============================] - 0s 13ms/step - loss: 0.6962 - accuracy: 0.6250 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 4/50
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6933 - accuracy: 0.5312 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 5/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6940 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/50
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6936 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6936 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 8/50
# 16/16 [==============================] - 0s 14ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 9/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.7341 - accuracy: 0.6250 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 10/50
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 11/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 12/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 13/50
# 16/16 [==============================] - 0s 11ms/step - loss: 0.6937 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/50
# 16/16 [==============================] - 0s 12ms/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6930 - val_accuracy: 0.5000
# Epoch 15/50
# 16/16 [==============================] - 0s 12ms/step - loss: 0.7176 - accuracy: 0.3750 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 16/50
# 16/16 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.4375 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 17/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 18/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.7028 - accuracy: 0.5312 - val_loss: 0.6886 - val_accuracy: 0.5000
# Epoch 19/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.7063 - accuracy: 0.4688 - val_loss: 0.6592 - val_accuracy: 0.5000
# Epoch 20/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6859 - accuracy: 0.3750 - val_loss: 0.6686 - val_accuracy: 0.5000
# Epoch 21/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6378 - accuracy: 0.5312 - val_loss: 0.5796 - val_accuracy: 0.6250
# Epoch 22/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.7201 - accuracy: 0.5625 - val_loss: 0.6910 - val_accuracy: 0.7500
# Epoch 23/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6937 - accuracy: 0.5938 - val_loss: 0.6934 - val_accuracy: 0.5000
# Epoch 24/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.7061 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 25/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6957 - accuracy: 0.3750 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 26/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 27/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 28/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 29/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6937 - accuracy: 0.4688 - val_loss: 0.6928 - val_accuracy: 0.5000
# Epoch 30/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6780 - accuracy: 0.5938 - val_loss: 0.8815 - val_accuracy: 0.5000
# Epoch 31/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.7746 - accuracy: 0.4688 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 32/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6937 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 33/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 34/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 35/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6937 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 36/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6946 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 37/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6937 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 38/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 39/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6925 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 40/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 41/50
# 16/16 [==============================] - 0s 9ms/step - loss: 0.6934 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 42/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 43/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6939 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 44/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 45/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6930 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 46/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6924 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 47/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6921 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 48/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 49/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 50/50
# 16/16 [==============================] - 0s 8ms/step - loss: 0.6947 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000

# %%
model.save(os.path.join(path_to_model, 'cnn.pth'))

# %%
#Visualize Result
# Plot training & validation accuracy values
plt.plot(rnn.history['accuracy'])
plt.plot(rnn.history['val_accuracy'])
plt.title('LSTM Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('1D-CNN Model accuracy for subject 12.png')
plt.show()

# Plot training & validation loss values
plt.plot(rnn.history['loss'])
plt.plot(rnn.history['val_loss'])
plt.title('LSTM Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('1D-CNN Model loss for subject 12')
plt.show()

# %% [markdown]
# ### **Visualize the Results**

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
model.save(os.path.join(path_to_model, 'cnn64.pth'))
